# %%
# Install Libraries
# !pip install textblob
# !pip instal
# !pip install pycountry
# !pip install langdetect
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# ERROR: unknown command "instal" - maybe you meant "install"
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 68.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681832 sha256=90f346472bb382de6b1d6802099ad3b2febf0660df6ab1c5e0fea7787cedc260
#   Stored in directory: /root/.cache/pip/wheels/03/57/cc/290c5252ec97a6d78d36479a3c5e5ecc76318afcb241ad9dbe
# Successfully built pycountry
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 21.4 MB/s eta 0:00:00
# ...

# %%
# Import Libraries
from textblob import TextBlob
import sys
import tweepy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import nltk
import pycountry
import re
import string
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from langdetect import detect
from nltk.stem import SnowballStemmer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Authentication
consumerKey = "8of7RebpWgyASxl2kCyAhMfn5"
consumerSecret = "hkVMsACvcCfcKBgvj85FxodIs0BgjKSUXHlja2Gqsl5Id3kHF7"
accessToken = "1313610457903779842-Tuucn5d5Lblg6gNlRtqM6NTbphT7NS"
accessTokenSecret = "oMnak0MlMhdsw6klNlJI8qU0U7lsDCOTRk5H9KBXaOPEA"
auth = tweepy.OAuthHandler(consumerKey, consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)
api = tweepy.API(auth)

# %%
import tweepy

client = tweepy.Client("AAAAAAAAAAAAAAAAAAAAAF%2F2ngEAAAAAkAFIurGwmJZ%2BoqkZeyHUOuowVlM%3DxeU7IoP859BAEXXvnnsXmGhJG688xIdP5Y9dd9ewu92PGUpEP8")

# %%
client = tweepy.Client(
    consumer_key="8of7RebpWgyASxl2kCyAhMfn5",
    consumer_secret="hkVMsACvcCfcKBgvj85FxodIs0BgjKSUXHlja2Gqsl5Id3kHF7",
    access_token="1313610457903779842-Tuucn5d5Lblg6gNlRtqM6NTbphT7NS",
    access_token_secret="oMnak0MlMhdsw6klNlJI8qU0U7lsDCOTRk5H9KBXaOPEA"
)

# %%
oauth2_user_handler = tweepy.OAuth2UserHandler(
    client_id="RnJVa1k0SVNOQ2Z6SEpQdjNwbnI6MTpjaQ",
    redirect_uri="https://eozvf4iufuqofks.m.pipedream.net",
    scope=["tweet.read"],
    # Client Secret is only necessary if using a confidential client
    client_secret="SCyqz26BpvdoRzACWxIM62B3zpGSFpM_Q9Nay-K5tRiQtP6WXz"
)

# %%
# Import necessary libraries
import tweepy
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')

# Set up the Twitter API client using credentials from Twitter Developer Acc
consumer_key="8of7RebpWgyASxl2kCyAhMfn5"
consumer_secret="hkVMsACvcCfcKBgvj85FxodIs0BgjKSUXHlja2Gqsl5Id3kHF7"
access_token="1313610457903779842-Tuucn5d5Lblg6gNlRtqM6NTbphT7NS"
access_token_secret="oMnak0MlMhdsw6klNlJI8qU0U7lsDCOTRk5H9KBXaOPEA"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# Set up the sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Search for tweets about chatgpt
# Search for tweets about chatgpt
tweets = api.search_tweets("chatgpt",lang="en", count=100)


# Initialize the lists to save tweets based on the polarity score
neutral_list = []
negative_list = []
positive_list = []
Total_tweets = 0

# Analyze the sentiment of the tweets
for tweet in tweets:
    Total_tweets +=1
    text = tweet.text     

    # Get the polarity score for the tweet
    sentiment = analyzer.polarity_scores(text)

    if sentiment["compound"] > 0:
        positive_list.append(text)\\twitter_locations_01 (1).ipynb
    elif sentiment["compound"] < 0:
        negative_list.append(text)
    elif sentiment["compound"] == 0:
        neutral_list.append(text)

# Print the numbers
print(f'Total tweets : {Total_tweets}')
print(f'Positive tweets : {len(positive_list)}')    
print(f'Negative tweets: {len(negative_list)}')     
print(f'Neutral : {len(neutral_list)}')     

# Print all positive tweets
for tweet in positive_list:
  print(tweet)

# Print all negative tweets
for tweet in negative_list:
  print(tweet)
# Out:
#   File "<ipython-input-25-855339739b92>", line 40
#     positive_list.append(text)\\twitter_locations_01 (1).ipynb
#                                ^
# SyntaxError: unexpected character after line continuation character

# %%
print(oauth2_user_handler.get_authorization_url())
# Out:
# https://twitter.com/i/oauth2/authorize?response_type=code&client_id=RnJVa1k0SVNOQ2Z6SEpQdjNwbnI6MTpjaQ&redirect_uri=https%3A%2F%2Feozvf4iufuqofks.m.pipedream.net&scope=tweet.read&state=n972EsrJU0Cl9uP3OE1ehc7RRLn4LT&code_challenge=NnoS32ZNsXVkrYCBVol_GQIwuTUkkigMpoKOn5lIMJo&code_challenge_method=S256

# %%
access_token = oauth2_user_handler.fetch_token(
    "https://eozvf4iufuqofks.m.pipedream.net"
)

# %%
client = tweepy.Client("1313610457903779842-Tuucn5d5Lblg6gNlRtqM6NTbphT7NS")

# %%
print("Please navigate here and authorize the app: " + auth_url)
# Out:
# Please navigate here and authorize the app: https://api.twitter.com/oauth/authorize?oauth_token=-Lz_RQAAAAABnvZfAAABiFC2SxY

# %%
import tweepy
import webbrowser

# Consumer keys from Twitter App
consumer_key = '8of7RebpWgyASxl2kCyAhMfn5'
consumer_secret = 'hkVMsACvcCfcKBgvj85FxodIs0BgjKSUXHlja2Gqsl5Id3kHF7'

# Create OAuthHandler object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback='oob')

# Get authorization URL and open in webbrowser
auth_url = auth.get_authorization_url()
webbrowser.open(auth_url)

# This will open a new tab with Twitter asking you to authorize the app
# After you authorize the app, it will give you a code (the oauth_verifier)

# Paste that code here
verifier = input('Verifier code: ')

# Use the verifier to get the access tokens
auth.get_access_token(verifier)

# Now auth.access_token and auth.access_token_secret contain the access tokens
# Out:
# Verifier code: 7447490
# ---------------------------------------------------------------------------
# TokenRequestDenied                        Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/tweepy/auth.py in get_access_token(self, verifier)
#      94             )
# ---> 95             resp = self.oauth.fetch_access_token(url)
#      96             self.access_token = resp['oauth_token']
#
# /usr/local/lib/python3.10/dist-packages/requests_oauthlib/oauth1_session.py in fetch_access_token(self, url, verifier, **request_kwargs)
#     322             raise VerifierMissing("No client verifier has been set.")
# --> 323         token = self._fetch_token(url, **request_kwargs)
#     324         log.debug("Resetting verifier attribute, should not be used anymore.")
#
# /usr/local/lib/python3.10/dist-packages/requests_oauthlib/oauth1_session.py in _fetch_token(self, url, **request_kwargs)
# ...

# %%
print(oauth2_user_handler.get_authorization_url())
# Out:
# https://twitter.com/i/oauth2/authorize?response_type=code&client_id=RnJVa1k0SVNOQ2Z6SEpQdjNwbnI6MTpjaQ&redirect_uri=https%3A%2F%2F127.0.0.1%3A9000&scope=tweet.read&state=GhXxuf7zWggSmhSH3MziRR1bIgkimg&code_challenge=WWMewbtRcSKrXmWV6802fiTlYRKZ6FmZlX2c9r49ZkM&code_challenge_method=S256

# %%
access_token = oauth2_user_handler.fetch_token(
    "Authorization Response URL here"
)

# %%
#Sentiment Analysis

def percentage(part,whole):
    return 100 * float(part)/float(whole) 

keyword = input("Please enter keyword or hashtag to search: ")
noOfTweet = int(input ("Please enter how many tweets to analyze: "))


tweets = tweepy.Cursor(api.search_tweets, q=keyword).items(noOfTweet)

positive  = 0
negative = 0
neutral = 0
polarity = 0
tweet_list = []
neutral_list = []
negative_list = []
positive_list = []

for tweet in tweets:
    
    #print(tweet.text)
    tweet_list.append(tweet.text)
    analysis = TextBlob(tweet.text)
    score = SentimentIntensityAnalyzer().polarity_scores(tweet.text)
    neg = score['neg']
    neu = score['neu']
    pos = score['pos']
    comp = score['compound']
    polarity += analysis.sentiment.polarity
    
    if neg > pos:
        negative_list.append(tweet.text)
        negative += 1

    elif pos > neg:
        positive_list.append(tweet.text)
        positive += 1
    
    elif pos == neg:
        neutral_list.append(tweet.text)
        neutral += 1

positive = percentage(positive, noOfTweet)
negative = percentage(negative, noOfTweet)
neutral = percentage(neutral, noOfTweet)
polarity = percentage(polarity, noOfTweet)
positive = format(positive, '.1f')
negative = format(negative, '.1f')
neutral = format(neutral, '.1f')
# Out:
# Please enter keyword or hashtag to search: a
# Please enter how many tweets to analyze: 1
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-91-346502bb1119> in <cell line: 21>()
#      19 positive_list = []
#      20
# ---> 21 for tweet in tweets:
#      22
#      23     #print(tweet.text)
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
#     287             while len(self.current_page) == 0:
# ...

# %%
from tweepy import OAuthHandler, API

# Authenticate with OAuth
auth = OAuthHandler('8of7RebpWgyASxl2kCyAhMfn5', 'hkVMsACvcCfcKBgvj85FxodIs0BgjKSUXHlja2Gqsl5Id3kHF7')
auth.set_access_token('1313610457903779842-Tuucn5d5Lblg6gNlRtqM6NTbphT7NS', 'oMnak0MlMhdsw6klNlJI8qU0U7lsDCOTRk5H9KBXaOPEA')

# Create an API object
api = API(auth)

# Define your query and other parameters
query = "Melbourne"
max_results = 100  # Maximum of 100 for 30-day endpoint
env_name = "1661490696333799425tensormatri"  # Replace with your dev environment name

# Call the premium search API
tweets = api.search_30_day(env_name, query, max_results=max_results)

# Process the tweets
for tweet in tweets:
    print(tweet.text)

# %%
import requests
import json

def create_url():
    query = "@TwitterDev -is:retweet"
    tweet_fields = "tweet.fields=author_id"
    url = "https://api.twitter.com/1.1/search/tweets.json?q={}&{}".format(
        query, tweet_fields
    )
    return url

def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """
    bearer_token = 'AAAAAAAAAAAAAAAAAAAAAF%2F2ngEAAAAAkAFIurGwmJZ%2BoqkZeyHUOuowVlM%3DxeU7IoP859BAEXXvnnsXmGhJG688xIdP5Y9dd9ewu92PGUpEP8'  # Replace with your Bearer Token
    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2FilteredStreamPython"
    return r

def connect_to_endpoint(url):
    response = requests.request("GET", url, auth=bearer_oauth)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

def main():
    url = create_url()
    json_response = connect_to_endpoint(url)
    print(json.dumps(json_response, indent=4))

if __name__ == "__main__":
    main()

# %%
api key 8of7RebpWgyASxl2kCyAhMfn5

api key secret hkVMsACvcCfcKBgvj85FxodIs0BgjKSUXHlja2Gqsl5Id3kHF7

bearer token AAAAAAAAAAAAAAAAAAAAAF%2F2ngEAAAAAkAFIurGwmJZ%2BoqkZeyHUOuowVlM%3DxeU7IoP859BAEXXvnnsXmGhJG688xIdP5Y9dd9ewu92PGUpEP8

access token 1313610457903779842-Tuucn5d5Lblg6gNlRtqM6NTbphT7NS

access token secret oMnak0MlMhdsw6klNlJI8qU0U7lsDCOTRk5H9KBXaOPEA

# %%
import tweepy
from textblob import TextBlob
from nltk.sentiment.vader import SentimentIntensityAnalyzer

#Sentiment Analysis
def percentage(part,whole):
    return 100 * float(part)/float(whole)

keyword = 'Melbourne'
noOfTweet = 100
tweets = tweepy.Cursor(api.search_tweets, q=keyword).items(noOfTweet)


positive = 0
negative = 0
neutral = 0
polarity = 0

tweet_list = []
neutral_list = []
negative_list = []
positive_list = []

for tweet in tweets:
    tweet_list.append(tweet.text)
    analysis = TextBlob(tweet.text)
    score = SentimentIntensityAnalyzer().polarity_scores(tweet.text)
    neg = score['neg']
    neu = score['neu']
    pos = score['pos']
    comp = score['compound']
    polarity += analysis.sentiment.polarity

    if neg > pos:
        negative_list.append(tweet.text)
        negative += 1
    elif pos > neg:
        positive_list.append(tweet.text)
        positive += 1
    elif pos == neg:
        neutral_list.append(tweet.text)
        neutral += 1

positive = percentage(positive, noOfTweet)
negative = percentage(negative, noOfTweet)
neutral = percentage(neutral, noOfTweet)
polarity = percentage(polarity, noOfTweet)

positive = format(positive, '.1f')
negative = format(negative,'.1f')
neutral = format(neutral,'.1f')

# Print or use these values further
print(f"Positive tweets: {positive}%")
print(f"Negative tweets: {negative}%")
print(f"Neutral tweets: {neutral}%")

# %%
curl "https://api.twitter.com/2/users/by/username/$USERNAME" -H "Authorization: Bearer $ACCESS_TOKEN"

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools

# Define the location and the query
loc = '14.6207775796981, -90.55610865667882, 10km'
query = 'trafico pizza geocode:"{}"'.format(loc)

# Scrape the tweets
df_coord = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(query).get_items(), 50))

# Extract the URL of each tweet
test = df_coord['url']

# Print the URLs
print(test.to_string())

# Save the URLs to a CSV file
test.to_csv('test_03.csv', index=False)
